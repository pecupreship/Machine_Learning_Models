# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.8

# %%
heart_data=pd.read_csv(r'C:\Users\NDE\Downloads\heart.csv')

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data=heart_data.rename(columns={'thalach':'thal'})

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thal  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1   168      0      1.0      2
# 1   53    1   0       140   203    1        0   155      1      3.1      0
# 2   70    1   0       145   174    0        1   125      1      2.6      0
# 3   61    1   0       148   203    0        1   161      0      0.0      2
# 4   62    0   0       138   294    1        1   106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data.shape
# Out:
# (1025, 14)

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thal        0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thal      1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [raw]
# Feature Selection Process using Filter method

# %%
#data = heart_data.values
#X=data[:,0:13]
#Y=data[:,13]

# %%
#from sklearn.feature_selection import SelectKBest
#from sklearn.feature_selection import chi2

# %%
#chi_best = SelectKBest(score_func=chi2)
#k_best = chi_best.fit(X,Y)

# %%
#np.set_printoptions()
#print(k_best.scores_)
#k_features = k_best.transform(X)

# %%
#Splitting Training_Test set

# %%
X = heart_data.drop(columns={'target', 'fbs'})
Y = heart_data['target']

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  restecg  thal  exang  oldpeak  slope  ca  \
# 0   52    1   0       125   212        1   168      0      1.0      2   2
# 1   53    1   0       140   203        0   155      1      3.1      0   0
# 2   70    1   0       145   174        1   125      1      2.6      0   0
# 3   61    1   0       148   203        1   161      0      0.0      2   1
# 4   62    0   0       138   294        1   106      0      1.9      1   3
#
#    thal
# 0     3
# 1     3
# 2     3
# 3     3
# 4     2

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %% [markdown]
# #Training the model

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\NDE\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
Accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print(Accuracy*100)
# Out:
# 85.24390243902438

# %%
X_test_prediction=model.predict(X_test)
Accuracy_test=accuracy_score(X_test_prediction, Y_test)

# %%
print(Accuracy_test*100)
# Out:
# 80.48780487804879

# %% [raw]
# Building Predictive model

# %%
input = (58,1,2,140,211,0,165,0,0,2,0,2)

# %% [raw]
# Conversion to numpy array

# %%
input_to_array = np.asarray(input)

# %% [raw]
# Reshaping the data

# %%
input_reshape = input_to_array.reshape(1,-1)

# %% [raw]
# Predict input

# %%
predict = model.predict(input_reshape)
# Out:
# C:\Users\NDE\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 predict = model.predict(input_reshape)
#
# File ~\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\linear_model\_base.py:332, in LinearClassifierMixin.decision_function(self, X)
#     329 check_is_fitted(self)
#     330 xp, _ = get_namespace(X)
# --> 332 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     333 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     334 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File ~\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\envs\Data_Science\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 8 features, but LogisticRegression is expecting 9 features as input.

# %%
print(predict)
# Out:
# [0]

# %%
if (predict[0]==0):
    print("The person has no heart disease")
else:
    print("The person has Heart disease")
    print("Visit the Cardiologist")
# Out:
# The person has no heart disease
